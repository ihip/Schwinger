# %% [markdown]
# $\frac{T}{\mu} = \frac{1}{a n_t} \sqrt{\frac{\pi \beta}{N_f}}$

# %%
n(sqrt(pi * 4 / 2))
# Out:
# 2.50662827463100

# %%
for i in range(1,65):
    print(i, n(sqrt(pi * 4 / 2) / i))
# Out:
# 1 2.50662827463100
# 2 1.25331413731550
# 3 0.835542758210333
# 4 0.626657068657750
# 5 0.501325654926200
# 6 0.417771379105167
# 7 0.358089753518714
# 8 0.313328534328875
# 9 0.278514252736778
# 10 0.250662827463100
# 11 0.227875297693727
# 12 0.208885689552583
# 13 0.192817559587000
# 14 0.179044876759357
# 15 0.167108551642067
# 16 0.156664267164438
# 17 0.147448722037118
# 18 0.139257126368389
# 19 0.131927803927947
# 20 0.125331413731550
# 21 0.119363251172905
# 22 0.113937648846864
# 23 0.108983838027435
# 24 0.104442844776292
# 25 0.100265130985240
# 26 0.0964087797935000
# 27 0.0928380842455926
# 28 0.0895224383796786
# 29 0.0864354577458966
# 30 0.0835542758210333
# 31 0.0808589766010000
# 32 0.0783321335822188
# 33 0.0759584325645758
# 34 0.0737243610185588
# 35 0.0716179507037429
# 36 0.0696285631841944
# 37 0.0677467101251622
# 38 0.0659639019639737
# 39 0.0642725198623333
# 40 0.0626657068657750
# 41 0.0611372749910000
# 42 0.0596816255864524
# 43 0.0582936808053721
# ...
